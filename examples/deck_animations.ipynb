# %% [markdown]
# # qBraid deck — live animations in the notebook
#
# The design deck's figures are self-registering custom elements run **as-is** inside sandboxed `<iframe srcdoc>` cells (iframes execute their own scripts, so Jupyter's markdown sanitiser doesn't strip them). `graph-stage` is pure Canvas 2D (offline); `concept-figure` and `mapping-stage` use three.js (loaded from unpkg — needs network, or point `deckwidgets.THREE_SRC` at a local copy).

# %%
import sys, os
_root = os.getcwd()
if not os.path.isdir(os.path.join(_root, 'src')): _root = os.path.dirname(_root)
sys.path.insert(0, os.path.join(_root, 'src'))
import deckwidgets as dw

# %% [markdown]
# ## Repeated MIS → graph colouring  (the channel-plan animation)

# %%
dw.graph_stage("coloring", height=560)

# %% [markdown]
# ## One MIS resolves to channel 1

# %%
dw.graph_stage("mis", height=520)

# %% [markdown]
# ## Why towers conflict — 3D towers (three.js)

# %%
dw.concept_figure("power", height=260)

# %% [markdown]
# ## Cell sites → coverage graph → atom register (three.js)

# %%
dw.mapping_stage(height=560)
